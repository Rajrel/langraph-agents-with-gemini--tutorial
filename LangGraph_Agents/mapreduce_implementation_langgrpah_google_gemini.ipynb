# %%
import os
import getpass


def _set_env(name: str):
    if not os.getenv(name):
        os.environ[name] = getpass.getpass(f"{name}: ")


_set_env("GOOGLE_API_KEY")

# %%
import getpass
import os

if "MISTRAL_API_KEY" not in os.environ:
    os.environ["MISTRAL_API_KEY"] = getpass.getpass("Enter your Mistral API key: ")

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
# !python -m pip install -qU langchain_anthropic

# %%
import operator
from typing import Annotated, TypedDict
from langchain_core.pydantic_v1 import BaseModel
#from pydantic import BaseModel # Does not work with Pydantic V2
from langchain_google_genai import ChatGoogleGenerativeAI
#from langchain_ollama import ChatOllama
from langgraph.constants import Send
from langgraph.graph import END, StateGraph, START
from langchain_mistralai import ChatMistralAI
from langchain_anthropic import ChatAnthropic

# Define the model
model = ChatGoogleGenerativeAI(model= "gemini-1.5-flash-latest") #"gemini-1.5-pro-exp-0827")
#model = ChatGoogleGenerativeAI(model= "gemini-1.5-pro-exp-0827") - better results but quota exhaustion

#model = ChatOllama(model="llama3.1:8b")

#model = ChatMistralAI(model="mistral-large-latest") #"open-mistral-7b")

#model = ChatAnthropic(model="claude-3-5-sonnet-20240620")
# Define the prompts
step1_prompt = """Step 1: I have a problem related to {input}. Could you brainstorm three distinct solutions? Please consider a variety of factors such as {perfect_factors}"""

step2_prompt = """Step 2: For each of the three proposed solutions in Step1, 
Review their potential. Consider their pros and cons, initial effort needed, implementation difficulty, potential challenges, and the expected outcomes. Assign a probability of success and a confidence level to each option based on these factors.

Solutions:
{solutions}"""

step3_prompt = """Step 3: For each solution, deepen the thought process. Generate potential scenarios, strategies for implementation, any necessary partnerships or resources, and how potential obstacles might be overcome. Also, consider any potential unexpected outcomes and how they might be handled.

Evaluation:
{review}"""

step4_prompt = """Step 4: Based on the evaluations and scenarios, rank the solutions in order of promise. Provide a justification for each ranking and offer any final thoughts or considerations for each solution.

Detailed analysis:
{deepen_thought_process}"""

# Define the output structures
class Solutions(BaseModel):
    """Solutions Provided"""
    solutions: list[str]

class Review(BaseModel):
    """Reviews on Solutions"""
    review: str

class DeepThought(BaseModel):
    """Deep Thoughts on Reviews"""
    deep_thought: str

class RankedSolutions(BaseModel):
    """Ranking of Solutions"""
    ranked_solutions: str

# Define the overall state
class OverallState(TypedDict):
    """Overall State Flow"""
    input: str
    perfect_factors: str
    solutions: Annotated[list[str], operator.add]
    reviews: Annotated[list[str], operator.add]
    deep_thoughts: Annotated[list[str], operator.add]
    ranked_solutions: str

# Define the state for individual solution processing
class SolutionState(TypedDict):
    """Individual Processiing of SolutionState"""
    solution: str
# Out:
# c:\Users\dpokh\langchain-academy\lc-academy-env\Lib\site-packages\IPython\core\interactiveshell.py:3577: LangChainDeprecationWarning: As of langchain-core 0.3.0, LangChain uses pydantic v2 internally. The langchain_core.pydantic_v1 module was a compatibility shim for pydantic v1, and should no longer be used. Please update the code to import from Pydantic directly.
#
# For example, replace imports like: `from langchain_core.pydantic_v1 import BaseModel`
# with: `from pydantic import BaseModel`
# or the v1 compatibility namespace if you are working in a code base that has not been fully upgraded to pydantic 2 yet. 	from pydantic.v1 import BaseModel
#
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
# Graph components
def generate_solutions(state: OverallState):
    prompt = step1_prompt.format(input=state["input"], perfect_factors=state["perfect_factors"])
    response = model.with_structured_output(Solutions).invoke(prompt)
    return {"solutions": response.solutions}

def evaluate_solution(state: SolutionState):
    prompt = step2_prompt.format(solutions=state["solution"])
    response = model.with_structured_output(Review).invoke(prompt)
    return {"reviews": [response.review]}

def deepen_thought(state: SolutionState):
    prompt = step3_prompt.format(review=state["solution"])
    response = model.with_structured_output(DeepThought).invoke(prompt)
    return {"deep_thoughts": [response.deep_thought]}

def rank_solutions(state: OverallState):
    deep_thoughts = "\n\n".join(state["deep_thoughts"])
    prompt = step4_prompt.format(deepen_thought_process=deep_thoughts)
    response = model.with_structured_output(RankedSolutions).invoke(prompt)
    return {"ranked_solutions": response.ranked_solutions}

# Define the mapping logic
def continue_to_evaluation(state: OverallState):
    return [Send("evaluate_solution", {"solution": s}) for s in state["solutions"]]

def continue_to_deep_thought(state: OverallState):
    return [Send("deepen_thought", {"solution": r}) for r in state["reviews"]]

# %%
# Construct the graph
graph = StateGraph(OverallState)

graph.add_node("generate_solutions", generate_solutions)
graph.add_node("evaluate_solution", evaluate_solution)
graph.add_node("deepen_thought", deepen_thought)
graph.add_node("rank_solutions", rank_solutions)

graph.add_edge(START, "generate_solutions")
graph.add_conditional_edges("generate_solutions", continue_to_evaluation, ["evaluate_solution"])
graph.add_conditional_edges("evaluate_solution", continue_to_deep_thought, ["deepen_thought"])
graph.add_edge("deepen_thought", "rank_solutions")
graph.add_edge("rank_solutions", END)

app = graph.compile()

# %%
import textwrap
from pprint import pprint

# Call the graph
for s in app.stream({
    "input": "improving public transportation in a growing city",
    "perfect_factors": "cost, efficiency, environmental impact, and user experience"
}):
    pprint(s)
# Out:
# Key 'title' is not supported in schema, ignoring
# Key 'title' is not supported in schema, ignoring
# Key 'title' is not supported in schema, ignoring
# Key 'title' is not supported in schema, ignoring
# Key 'title' is not supported in schema, ignoring
# Key 'title' is not supported in schema, ignoring
# Key 'title' is not supported in schema, ignoring
# Key 'title' is not supported in schema, ignoring
# {'generate_solutions': {'solutions': ['Increase frequency of public '
#                                       'transportation routes',
#                                       'Implement a smart ticketing system with '
#                                       'real-time information',
#                                       'Invest in electric buses']}}
# {'evaluate_solution': {'reviews': ['Increase frequency of public '
#                                    'transportation routes']}}
# {'evaluate_solution': {'reviews': ['Invest in electric buses']}}
# Key 'title' is not supported in schema, ignoring
# Key 'title' is not supported in schema, ignoring
# Key 'title' is not supported in schema, ignoring
# Key 'title' is not supported in schema, ignoring
# Key 'title' is not supported in schema, ignoring
# Key 'title' is not supported in schema, ignoring
# {'evaluate_solution': {'reviews': ['Pros:\n'
#                                    '- Improved customer experience: A smart '
#                                    'ticketing system with real-time '
#                                    'information can provide customers with a '
#                                    'more efficient and convenient experience. '
#                                    'They can easily track the status of their '
#                                    'tickets, get updates on delays, and find '
#                                    'answers to their questions without having '
#                                    'to wait on hold.\n'
#                                    '- Increased efficiency: A smart ticketing '
#                                    'system can automate many tasks, such as '
#                                    'ticket routing, escalation, and reporting. '
#                                    'This can free up staff to focus on more '
#                                    'complex issues.\n'
#                                    '- Reduced costs: By automating tasks and '
#                                    'improving efficiency, a smart ticketing '
#                                    'system can help reduce costs associated '
#                                    'with customer support.\n'
#                                    '- Better data insights: A smart ticketing '
#                                    'system can collect data on customer '
#                                    'interactions, which can be used to '
#                                    'identify trends and improve customer '
#                                    'service.\n'
#                                    '\n'
#                                    'Cons:\n'
#                                    '- Initial investment: Implementing a smart '
#                                    'ticketing system can require a significant '
#                                    'initial investment in software, hardware, '
#                                    'and training.\n'
#                                    '- Integration challenges: Integrating a '
#                                    'smart ticketing system with existing '
#                                    'systems can be challenging.\n'
#                                    '- Data security concerns: A smart '
#                                    'ticketing system will collect and store '
#                                    "sensitive customer data, so it's important "
#                                    'to ensure that the system is secure.\n'
#                                    '\n'
#                                    'Initial effort needed:\n'
#                                    '- High: Implementing a smart ticketing '
#                                    'system requires significant planning, '
#                                    'design, and development.\n'
#                                    '\n'
#                                    'Implementation difficulty:\n'
#                                    '- Moderate: Implementing a smart ticketing '
#                                    'system can be challenging, but there are '
#                                    'many pre-built solutions available that '
#                                    'can simplify the process.\n'
#                                    '\n'
#                                    'Potential challenges:\n'
#                                    '- Resistance to change: Some employees may '
#                                    'be resistant to using a new system.\n'
#                                    '- Data integration issues: Integrating the '
#                                    'system with existing systems can be '
#                                    'challenging.\n'
#                                    '- Security risks: The system must be '
#                                    'secure to protect customer data.\n'
#                                    '\n'
#                                    'Expected outcomes:\n'
#                                    '- Improved customer satisfaction\n'
#                                    '- Increased efficiency\n'
#                                    '- Reduced costs\n'
#                                    '- Better data insights\n'
#                                    '\n'
#                                    'Probability of success:\n'
#                                    '- High: With careful planning and '
#                                    'execution, a smart ticketing system has a '
#                                    'high probability of success.\n'
#                                    '\n'
#                                    'Confidence level:\n'
#                                    '- High: There are many successful examples '
#                                    'of smart ticketing systems in use '
#                                    'today.\n']}}
# {'deepen_thought': {'deep_thoughts': ['Increase frequency of public '
#                                       'transportation routes']}}
# {'deepen_thought': {'deep_thoughts': ['Invest in electric buses']}}
# Key 'title' is not supported in schema, ignoring
# Key 'title' is not supported in schema, ignoring
# {'deepen_thought': {'deep_thoughts': ['Scenario 1: A customer is experiencing '
#                                       'a technical issue with their account. '
#                                       'They submit a ticket through the smart '
#                                       'ticketing system. The system '
#                                       'automatically routes the ticket to the '
#                                       'appropriate support team based on the '
#                                       "customer's account type and the nature "
#                                       'of the issue. The support team can then '
#                                       "access the customer's account "
#                                       'information and history of interactions '
#                                       'to quickly understand the problem and '
#                                       'provide a solution.\n'
#                                       '\n'
#                                       'Strategy: Implement a knowledge-based '
#                                       'system that uses natural language '
#                                       'processing (NLP) to understand the '
#                                       "customer's issue and route it to the "
#                                       'appropriate team. This system should be '
#                                       'integrated with the existing customer '
#                                       'relationship management (CRM) system to '
#                                       'access account information and '
#                                       'history.\n'
#                                       '\n'
#                                       'Partnerships: Consider partnering with '
#                                       'a vendor specializing in NLP and CRM '
#                                       'integration.\n'
#                                       '\n'
#                                       'Obstacles: The accuracy of the NLP '
#                                       'system may be limited, leading to '
#                                       'incorrect routing. To mitigate this, '
#                                       'the system can be trained on a large '
#                                       'dataset of customer interactions and '
#                                       'feedback.\n'
#                                       '\n'
#                                       'Unexpected outcomes: The system might '
#                                       'identify new trends or patterns in '
#                                       'customer issues that were previously '
#                                       'unknown. This data can be used to '
#                                       'improve customer service and product '
#                                       'development.\n'
#                                       '\n'
#                                       'Scenario 2: A customer wants to know '
#                                       'the status of their order. They submit '
#                                       'a ticket through the smart ticketing '
#                                       'system. The system provides real-time '
#                                       "updates on the order's progress, "
#                                       'including estimated delivery time, '
#                                       'tracking information, and any potential '
#                                       'delays.\n'
#                                       '\n'
#                                       'Strategy: Integrate the smart ticketing '
#                                       'system with the order management system '
#                                       'to provide real-time updates. The '
#                                       'system can use machine learning to '
#                                       'predict potential delays and '
#                                       'proactively notify customers.\n'
#                                       '\n'
#                                       'Partnerships: Consider partnering with '
#                                       'a logistics company to provide '
#                                       'real-time tracking information.\n'
#                                       '\n'
#                                       'Obstacles: The accuracy of the order '
#                                       'management system may be limited, '
#                                       'leading to inaccurate updates. To '
#                                       'mitigate this, the system can be '
#                                       'trained on historical data to improve '
#                                       'its accuracy.\n'
#                                       '\n'
#                                       'Unexpected outcomes: The system might '
#                                       'identify areas where order fulfillment '
#                                       'can be optimized, leading to faster '
#                                       'delivery times and improved customer '
#                                       'satisfaction.\n'
#                                       '\n'
#                                       'Scenario 3: A customer has a question '
#                                       'about a product feature. They submit a '
#                                       'ticket through the smart ticketing '
#                                       'system. The system provides a list of '
#                                       'relevant articles and FAQs that answer '
#                                       "the customer's question. If the "
#                                       "customer's question is not answered, "
#                                       'the system can escalate the ticket to a '
#                                       'human support agent.\n'
#                                       '\n'
#                                       'Strategy: Build a knowledge base of '
#                                       'articles and FAQs that cover common '
#                                       'customer questions. The system should '
#                                       "use NLP to understand the customer's "
#                                       'question and provide relevant '
#                                       'information.\n'
#                                       '\n'
#                                       'Partnerships: Consider partnering with '
#                                       'a content management system (CMS) '
#                                       'vendor to create and manage the '
#                                       'knowledge base.\n'
#                                       '\n'
#                                       'Obstacles: The knowledge base may not '
#                                       'cover all possible customer questions. '
#                                       'To mitigate this, the system should be '
#                                       'continuously updated with new '
#                                       'information and feedback from '
#                                       'customers.\n'
#                                       '\n'
#                                       'Unexpected outcomes: The system might '
#                                       'identify areas where product '
#                                       'documentation can be improved, leading '
#                                       'to better customer understanding and '
#                                       'reduced support requests.\n']}}
# {'rank_solutions': {'ranked_solutions': '\n'
#                                         'Solution|Promise|Justification\n'
#                                         '---|---|---|\n'
#                                         'Invest in electric '
#                                         'buses|High|Electric buses can '
#                                         'significantly reduce greenhouse gas '
#                                         'emissions and improve air quality. '
#                                         'They are also quieter than '
#                                         'traditional diesel buses, which can '
#                                         'improve the quality of life for '
#                                         'residents living near bus routes.\n'
#                                         'Increase frequency of public '
#                                         'transportation '
#                                         'routes|Medium|Increasing the '
#                                         'frequency of public transportation '
#                                         'routes can make it more convenient '
#                                         'for people to use public '
#                                         'transportation, which can reduce '
#                                         'traffic congestion and air pollution. '
#                                         'However, the effectiveness of this '
#                                         'solution will depend on the specific '
#                                         'routes and the demand for public '
#                                         'transportation in the area.\n'
#                                         'Implement a knowledge-based system '
#                                         'that uses natural language processing '
#                                         "(NLP) to understand the customer's "
#                                         'issue and route it to the appropriate '
#                                         'team.|Low|While a knowledge-based '
#                                         'system could be helpful in improving '
#                                         'customer service, it is not clear how '
#                                         'effective it would be in addressing '
#                                         'the specific challenges faced by the '
#                                         'smart ticketing system. The system '
#                                         'would need to be carefully designed '
#                                         'and tested to ensure that it is '
#                                         'accurate and reliable.\n'}}
